# %% [markdown]
# # SQL QUERIES
#
# This notebook

# %%
# %run ./setup-sql-notebook.ipynb
# Out:
# 1
# 1
# 2

# %%
# %pip install duckdb
# Out:
# ...
#    ---------------------------------------- 9.8/9.8 MB 2.3 MB/s eta 0:00:00
# ...

# %%
folderpath = 'd:\DaThabor\Repositories\Mentorship\Mentorship-Program\\'
filename = 'airline_passenger_satisfaction.csv'

file = folderpath+filename

# %%
import pandas as pd
import duckdb

# %%
df = pd.read_csv(file)
df.head(5)
# Out:
#    ID  Gender  Age CustomerType TypeOfTravel     Class  FlightDistance  \
# 0   1    Male   48   First-time     Business  Business             821
# 1   2  Female   35    Returning     Business  Business             821
# 2   3    Male   41    Returning     Business  Business             853
# 3   4    Male   50    Returning     Business  Business            1905
# 4   5  Female   49    Returning     Business  Business            3470
#
#    DepartureDelay  ArrivalDelay  DepArrConv  ...  OnboardService  SeatComfort  \
# 0               2           5.0           3  ...               3            5
# 1              26          39.0           2  ...               5            4
# 2               0           0.0           4  ...               3            5
# 3               0           0.0           2  ...               5            5
# 4               0           1.0           3  ...               3            4
#
#    LegRoomService  Cleanliness  FoodAndDrink  InflightService  \
# ...
